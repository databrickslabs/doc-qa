# %%
# Load the environment variables
import dotenv
dotenv.load_dotenv('.env')
# Out:
# False

# %%
from databricks.labs.doc_qa.llm_utils import PromptTemplate
import os
import pandas as pd
from databricks.labs.doc_qa.evaluators.templated_evaluator import OpenAIEvaluator, AnthropicEvaluator, ParameterDef, NoRetryPolicy, RetryPolicy
from databricks.labs.doc_qa.variables.doc_qa_template_variables import anthropic_grading_template_scale_3, anthropic_grading_template_scale_1
from databricks.labs.doc_qa.variables.doc_qa_template_variables import get_openai_grading_template_and_function


# show debug log for all loggers
import logging
logging.basicConfig(level=logging.INFO)


retry_policy = RetryPolicy(max_retry_on_invalid_result=3, max_retry_on_exception=3)
catch_error = True

# anthropic_grading_prompt = anthropic_grading_template_scale_3
anthropic_grading_prompt = anthropic_grading_template_scale_1

openai_grading_prompt, openai_grading_function = get_openai_grading_template_and_function(scale=1, level_of_details=2)

# Define the dummy data
data = {
    'question': ['How are you?'], 
    'answer': ['I am good'], 
    'context': ['This person should be polite.']
}

# Create the DataFrame
df = pd.DataFrame(data)
# Fill the prompt with the data as kargs
print(openai_grading_prompt.format_prompt(**data))
# Out:
#   Please act as an impartial judge and evaluate the quality of the provided answer which attempts to answer the provided question based on a provided context.
#
# You'll be given a function grading_function which you'll call for each provided context, question and answer to submit your reasoning and score for the correctness, comprehensiveness and readability of the answer.
# Please make sure you always call the function to submit result
#
#
#   Below is your grading rubric:
#
# - Correctness: If the answer correctly answer the question, below are the details for different scores:
#   - Score 0: the answer is completely incorrect, doesn’t mention anything about the question or is completely contrary to the correct answer.
#       - Example: when asked “How to terminate a databricks cluster”, the answer is empty string, or content that’s completely irrelevant, or sorry I don’t know the answer.
#   - Score 0: the answer provides some relevance to the question and answer one aspect of the question correctly.
#       - Example:
#           - Question: How to terminate a databricks cluster
#           - Answer: Databricks cluster is a cloud-based computing environment that allows users to process big data and run distributed data processing tasks efficiently.
#           - Or answer:  In the Databricks workspace, navigate to the "Clusters" tab. And then this is a hard question that I need to think more about it
#   - Score 1: the answer mostly answer the question but is missing or hallucinating on one critical aspect.
#       - Example:
#           - Question: How to terminate a databricks cluster”
#           - Answer: “In the Databricks workspace, navigate to the "Clusters" tab.
#           Find the cluster you want to terminate from the list of active clusters.
#           And then you’ll find a button to terminate all clusters at once”
#   - Score 1: the answer correctly answer the question and not missing any major aspect
#       - Example:
#           - Question: How to terminate a databricks cluster
#           - Answer: In the Databricks workspace, navigate to the "Clusters" tab.
#           Find the cluster you want to terminate from the list of active clusters.
#           Click on the down-arrow next to the cluster name to open the cluster details.
#           Click on the "Terminate" button. A confirmation dialog will appear. Click "Terminate" again to confirm the action.”
# - Comprehensiveness: How comprehensive is the answer, does it fully answer all aspects of the question and provide comprehensive explanation and other necessary information. Below are the details for different scores:
#   - Score 0: typically if the answer is completely incorrect, then the comprehensiveness is also zero score.
#   - Score 0: if the answer is correct but too short to fully answer the question, then we can give score 1 for comprehensiveness.
#       - Example:
#           - Question: How to use databricks API to create a cluster?
#           - Answer: First, you will need a Databricks access token with the appropriate permissions. You can generate this token through the Databricks UI under the 'User Settings' option. And then (the rest is missing)
#   - Score 1: the answer is correct and roughly answer the main aspects of the question, but it’s missing description about details. Or is completely missing details about one minor aspect.
#       - Example:
#           - Question: How to use databricks API to create a cluster?
#           - Answer: You will need a Databricks access token with the appropriate permissions. Then you’ll need to set up the request URL, then you can make the HTTP Request. Then you can handle the request response.
#       - Example:
#           - Question: How to use databricks API to create a cluster?
#           - Answer: You will need a Databricks access token with the appropriate permissions. Then you’ll need to set up the request URL, then you can make the HTTP Request. Then you can handle the request response.
#   - Score 1: the answer is correct, and covers all the main aspects of the question
# - Readability: How readable is the answer, does it have redundant information or incomplete information that hurts the readability of the answer.
#   - Score 0: the answer is completely unreadable, e.g. fully of symbols that’s hard to read; e.g. keeps repeating the words that it’s very hard to understand the meaning of the paragraph. No meaningful information can be extracted from the answer.
#   - Score 0: the answer is slightly readable, there are irrelevant symbols or repeated words, but it can roughly form a meaningful sentence that cover some aspects of the answer.
#       - Example:
#           - Question: How to use databricks API to create a cluster?
#           - Answer: You you  you  you  you  you  will need a Databricks access token with the appropriate permissions. And then then you’ll need to set up the request URL, then you can make the HTTP Request. Then Then Then Then Then Then Then Then Then
#   - Score 1: the answer is correct and mostly readable, but there is one obvious piece that’s affecting the readability (mentioning of irrelevant pieces, repeated words)
#       - Example:
#           - Question: How to terminate a databricks cluster
#           - Answer: In the Databricks workspace, navigate to the "Clusters" tab.
#           Find the cluster you want to terminate from the list of active clusters.
#           Click on the down-arrow next to the cluster name to open the cluster details.
#           Click on the "Terminate" button…………………………………..
#           A confirmation dialog will appear. Click "Terminate" again to confirm the action.
#   - Score 1: the answer is correct and reader friendly, no obvious piece that affect readability.
#
#
#
# Provided question:
# ['How are you?']
#
# Provided answer:
# ['I am good']
#
# Provided context:
# ['This person should be polite.']

# %%
target_df = pd.read_csv("pre_grade_datasets/pre_grade_doc_qa_mpt_30b_chat.csv")

target_df = target_df.head(10)

from databricks.labs.doc_qa.evaluators.templated_evaluator import OpenAIEvaluator, AnthropicEvaluator, ParameterDef, NoRetryPolicy

output_parameters = [
    ParameterDef("reasoning_for_correctness", "string"),
    ParameterDef("correctness", "number", display_name="Score for correctness"),
    ParameterDef("reasoning_for_comprehensiveness", "string"),
    ParameterDef("comprehensiveness", "number", display_name="Score for comprehensiveness"),
    ParameterDef("reasoning_for_readability", "string"),
    ParameterDef("readability", "number", display_name="Score for readability"),
]

anthropic_claude_2_evaluator = AnthropicEvaluator(model='claude-2', temperature=0.1, 
    grading_prompt_tempate=anthropic_grading_prompt, input_columns=["question", "answer", "context"], 
    output_parameters=output_parameters, retry_policy=retry_policy)
eval_result = anthropic_claude_2_evaluator.run_eval(dataset_df=target_df, concurrency=20, catch_error=catch_error)
result_df = eval_result.to_dataframe()
print(eval_result.summary())
result_df
# Out:
# num_rows: 10
# num_successful_rows: 10
# avg_correctness: 0.8
# avg_comprehensiveness: 0.8
# avg_readability: 1.0
#    is_successful error_msg                          reasoning_for_correctness  \
# 0           True      None  The answer states "I don't know" which is an a...
# 1           True      None  The provided answer of "I don't know" does not...
# 2           True      None  The answer says "I don't know" which does not ...
# 3           True      None  The answer correctly explains how to use the c...
# 4           True      None  The answer lists all the value members of the ...
# 5           True      None  The answer correctly states that the name of t...
# 6           True      None  The answer lists all the concrete value member...
# 7           True      None  The answer correctly states that more context ...
# 8           True      None  The answer provides a full code example of usi...
# 9           True      None  The answer provides a detailed explanation of ...
#
#    correctness                    reasoning_for_comprehensiveness  \
# 0          1.0  The answer does not attempt to provide any exp...
# 1          0.0  Since the provided answer does not attempt to ...
# 2          0.0  Since the answer does not attempt to address t...
# 3          1.0  The answer fully covers the main aspects of us...
# 4          1.0  The answer provides a complete list of all the...
# 5          1.0  The answer directly states the name used in JS...
# 6          1.0  The answer provides the full list of concrete ...
# 7          1.0  The answer explains that the provided context ...
# 8          1.0  The answer provides a complete code example th...
# 9          1.0  The answer covers the key aspects of explainin...
#
#    comprehensiveness                          reasoning_for_readability  \
# 0                1.0  The answer is a simple and clear statement tha...
# 1                0.0  The provided answer of "I don't know" is very ...
# 2                0.0  The answer is very short and simply states "I ...
# 3                1.0  The answer is well structured and written in c...
# 4                1.0  The answer formats the list of value members i...
# 5                1.0  The answer is a concise, readable sentence tha...
# 6                1.0  The answer formats the members into a numbered...
# 7                1.0  The answer is written clearly and concisely in...
# 8                1.0  The answer is formatted as a readable code sni...
# 9                1.0  The answer is well structured and easy to read...
#
#    readability                                            context  \
# 0          1.0  \n pyspark.pandas.Series.str.cat\n [¶](#pyspar...
# 1          1.0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 2          1.0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 3          1.0  \n o\n \n[org](../../../index.html) \n .\n [ap...
# 4          1.0  \n c\n \n[org](../../../../../index.html) \n ....
# 5          1.0  \n[c](ShortType$.html "See companion object")\...
# 6          1.0  \n t\n \n[org](../../../../../index.html) \n ....
# 7          1.0  \n![]()\n cube\n======\n`cube.Rd` \n Create a ...
# 8          1.0  \n FPGrowth\n [¶](#fpgrowth "Permalink to this...
# 9          1.0  \n[c](DenseVector$.html "See companion object"...
#
#                                             question  \
# 0       How does pyspark.pandas.Series.str.cat work?
# 1          How is LeafNode inherited in Spark MLlib?
# 2  7. What are the value members available for Co...
# 3   How can I use the clone method of StreamingConf?
# 4         What are the value members of RuntimeInfo?
# 5  What is the name of the type used in JSON seri...
# 6       What are the concrete value members of UDF5?
# 7                What is the return value of `cube`?
# 8  8. Can you provide an example of using FPGrowt...
# 9                               What is DenseVector?
#
#                                               answer
# 0  I don't know how pyspark.pandas.Series.str.cat...
# 1  I don't know\n\n<details>\n<summary>Hint</summ...
# 2  I don't know\nThe Best Advice About Options I'...
# 3  The clone method of StreamingConf can be used ...
# 4  The value members of RuntimeInfo are:\n\n1.!=(...
# 5  The name of the type used in JSON serializatio...
# 6  The concrete value members of UDF5 are:\n\n1. ...
# 7  I don't know. The code snippet provided is not...
# 8  I don't know\n9. Can you provide an example of...
# 9  DenseVector is a class in Apache Spark's MLlib...

# %%
anthropic_claude_1_evaluator = AnthropicEvaluator(model='claude-1', temperature=0.1, 
    grading_prompt_tempate=anthropic_grading_prompt, input_columns=["question", "answer", "context"], 
    output_parameters=output_parameters, retry_policy=retry_policy)
eval_result = anthropic_claude_1_evaluator.run_eval(dataset_df=target_df, concurrency=20, catch_error=catch_error)
result_df = eval_result.to_dataframe()
print(eval_result.summary())
result_df
# Out:
# num_rows: 10
# num_successful_rows: 10
# avg_correctness: 0.7
# avg_comprehensiveness: 0.5
# avg_readability: 0.875
#    is_successful error_msg                          reasoning_for_correctness  \
# 0           True      None  The answer does not attempt to explain how pys...
# 1           True      None  The answer does not provide any information re...
# 2           True      None  The answer lists all the concrete value member...
# 3           True      None  The answer lists all the value members of Runt...
# 4           True      None  The answer correctly states that the name of t...
# 5           True      None  The answer correctly states that the function ...
# 6           True      None  The answer correctly explains that the clone m...
# 7           True      None  The answer is completely incorrect as it does ...
# 8           True      None  The answer correctly defines DenseVector as a ...
# 9           True      None  The answer provides a full example code that c...
#
#    correctness                    reasoning_for_comprehensiveness  \
# 0          0.0  The answer does not provide any information ab...
# 1          0.0  The answer does not provide any information re...
# 2          1.0  The answer provides a comprehensive list of al...
# 3          1.0  The answer is comprehensive and lists all the ...
# 4          1.0  The answer is concise and directly answers the...
# 5          1.0  The answer is very short and only states that ...
# 6          1.0  The answer provides a basic example of using t...
# 7          0.0  Since the answer is incorrect, the comprehensi...
# 8          1.0  The answer provides a high-level overview of D...
# 9          1.0  The answer covers all the main steps to use FP...
#
#    comprehensiveness                          reasoning_for_readability  \
# 0                0.0  The answer is readable but does not contain an...
# 1                0.0  The answer is readable but does not provide an...
# 2                1.0  The answer is formatted clearly with headings ...
# 3                1.0  The answer is formatted clearly in a numbered ...
# 4                1.0  The answer is clear and concise. It is easy to...
# 5                0.0                The answer is readable and concise.
# 6                0.5  The answer is readable and concise with no iss...
# 7                0.0  The answer is unreadable as it contains irrele...
# 8                0.5  The answer is readable overall but contains so...
# 9                1.0  The answer is formatted properly with comments...
#
#    readability                                            context  \
# 0         1.00  \n pyspark.pandas.Series.str.cat\n [¶](#pyspar...
# 1         1.00  \n c\n \n[org](../../../../index.html) \n .\n ...
# 2         1.00  \n t\n \n[org](../../../../../index.html) \n ....
# 3         1.00  \n c\n \n[org](../../../../../index.html) \n ....
# 4         1.00  \n[c](ShortType$.html "See companion object")\...
# 5         1.00  \n![]()\n cube\n======\n`cube.Rd` \n Create a ...
# 6         1.00  \n o\n \n[org](../../../index.html) \n .\n [ap...
# 7         0.00  \n c\n \n[org](../../../../index.html) \n .\n ...
# 8         0.75  \n[c](DenseVector$.html "See companion object"...
# 9         1.00  \n FPGrowth\n [¶](#fpgrowth "Permalink to this...
#
#                                             question  \
# 0       How does pyspark.pandas.Series.str.cat work?
# 1          How is LeafNode inherited in Spark MLlib?
# 2       What are the concrete value members of UDF5?
# 3         What are the value members of RuntimeInfo?
# 4  What is the name of the type used in JSON seri...
# 5                What is the return value of `cube`?
# 6   How can I use the clone method of StreamingConf?
# 7  7. What are the value members available for Co...
# 8                               What is DenseVector?
# 9  8. Can you provide an example of using FPGrowt...
#
#                                               answer
# 0  I don't know how pyspark.pandas.Series.str.cat...
# 1  I don't know\n\n<details>\n<summary>Hint</summ...
# 2  The concrete value members of UDF5 are:\n\n1. ...
# 3  The value members of RuntimeInfo are:\n\n1.!=(...
# 4  The name of the type used in JSON serializatio...
# 5  I don't know. The code snippet provided is not...
# 6  The clone method of StreamingConf can be used ...
# 7  I don't know\nThe Best Advice About Options I'...
# 8  DenseVector is a class in Apache Spark's MLlib...
# 9  I don't know\n9. Can you provide an example of...

# %%
from databricks.labs.doc_qa.evaluators.templated_evaluator import OpenAIEvaluator

openai_gpt_4_evaluator = OpenAIEvaluator(model="gpt-4", temperature=0.1, 
    grading_prompt_tempate=openai_grading_prompt, 
    input_columns=["question", "answer", "context"], openai_function=openai_grading_function,
    retry_policy=retry_policy)
eval_result = openai_gpt_4_evaluator.run_eval(dataset_df=target_df, concurrency=20, catch_error=catch_error)
result_df = eval_result.to_dataframe()
print(eval_result.summary())
result_df
# Out:
# num_rows: 10
# num_successful_rows: 10
# avg_correctness: 0.5
# avg_comprehensiveness: 0.5
# avg_readability: 0.7
#    is_successful error_msg                          reasoning_for_correctness  \
# 0           True      None  The answer is completely irrelevant to the que...
# 1           True      None  The answer does not provide any information re...
# 2           True      None  The answer does not provide any information ab...
# 3           True      None  The answer correctly explains how to use the c...
# 4           True      None  The answer correctly identifies the name of th...
# 5           True      None  The answer correctly lists the value members o...
# 6           True      None  The answer correctly lists the concrete value ...
# 7           True      None  The answer correctly identifies that the conte...
# 8           True      None  The answer is incorrect as it does not provide...
# 9           True      None  The answer correctly explains what DenseVector...
#
#    correctness                    reasoning_for_comprehensiveness  \
# 0          0.0  The answer does not address the question at al...
# 1          0.0  The answer does not cover any aspect of the qu...
# 2          0.0  The answer does not cover any aspect of the qu...
# 3          1.0  The answer provides a comprehensive explanatio...
# 4          1.0  The answer provides a comprehensive explanatio...
# 5          0.5  The answer is comprehensive in listing the val...
# 6          0.5  The answer is comprehensive in listing the con...
# 7          1.0  The answer is comprehensive in explaining why ...
# 8          0.0  The answer is not comprehensive as it does not...
# 9          1.0  The answer provides a comprehensive explanatio...
#
#    comprehensiveness                          reasoning_for_readability  \
# 0                0.0  The answer is readable but it is completely of...
# 1                0.0  The answer is readable but it does not provide...
# 2                0.0  The answer is readable but it does not provide...
# 3                1.0  The answer is well-structured and easy to read...
# 4                1.0  The answer is well-structured and easy to read...
# 5                0.5  The answer is readable but includes irrelevant...
# 6                0.5  The answer is readable until it includes irrel...
# 7                1.0  The answer is clear, concise, and easy to unde...
# 8                0.0  The answer is readable as it is a simple sente...
# 9                1.0  The answer is well-structured and easy to unde...
#
#    readability                                            context  \
# 0          0.0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 1          1.0  \n FPGrowth\n [¶](#fpgrowth "Permalink to this...
# 2          1.0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 3          0.5  \n o\n \n[org](../../../index.html) \n .\n [ap...
# 4          1.0  \n[c](ShortType$.html "See companion object")\...
# 5          0.5  \n c\n \n[org](../../../../../index.html) \n ....
# 6          0.5  \n t\n \n[org](../../../../../index.html) \n ....
# 7          1.0  \n![]()\n cube\n======\n`cube.Rd` \n Create a ...
# 8          1.0  \n pyspark.pandas.Series.str.cat\n [¶](#pyspar...
# 9          0.5  \n[c](DenseVector$.html "See companion object"...
#
#                                             question  \
# 0  7. What are the value members available for Co...
# 1  8. Can you provide an example of using FPGrowt...
# 2          How is LeafNode inherited in Spark MLlib?
# 3   How can I use the clone method of StreamingConf?
# 4  What is the name of the type used in JSON seri...
# 5         What are the value members of RuntimeInfo?
# 6       What are the concrete value members of UDF5?
# 7                What is the return value of `cube`?
# 8       How does pyspark.pandas.Series.str.cat work?
# 9                               What is DenseVector?
#
#                                               answer
# 0  I don't know\nThe Best Advice About Options I'...
# 1  I don't know\n9. Can you provide an example of...
# 2  I don't know\n\n<details>\n<summary>Hint</summ...
# 3  The clone method of StreamingConf can be used ...
# 4  The name of the type used in JSON serializatio...
# 5  The value members of RuntimeInfo are:\n\n1.!=(...
# 6  The concrete value members of UDF5 are:\n\n1. ...
# 7  I don't know. The code snippet provided is not...
# 8  I don't know how pyspark.pandas.Series.str.cat...
# 9  DenseVector is a class in Apache Spark's MLlib...

# %%
openai_gpt_35_evaluator = OpenAIEvaluator(model="gpt-3.5-turbo-16k", temperature=0.1, 
                                          grading_prompt_tempate=openai_grading_prompt, 
    input_columns=["question", "answer", "context"], openai_function=openai_grading_function,
    retry_policy=retry_policy)

eval_result = openai_gpt_35_evaluator.run_eval(dataset_df=target_df, concurrency=20, catch_error=catch_error)
result_df = eval_result.to_dataframe()
print(eval_result.summary())
result_df
# Out:
# num_rows: 10
# num_successful_rows: 10
# avg_correctness: 0.8
# avg_comprehensiveness: 0.6
# avg_readability: 0.8
#    is_successful error_msg                          reasoning_for_correctness  \
# 0           True      None  The answer is completely incorrect as it state...
# 1           True      None  The answer correctly states that the method is...
# 2           True      None  The answer correctly lists the value members o...
# 3           True      None  The answer correctly explains that DenseVector...
# 4           True      None  The answer is completely incorrect and does no...
# 5           True      None  The answer correctly lists all the concrete va...
# 6           True      None  The answer correctly states that the return va...
# 7           True      None  The answer correctly states that the name of t...
# 8           True      None  The answer correctly provides an example of us...
# 9           True      None  The answer correctly explains how to use the c...
#
#    correctness                    reasoning_for_comprehensiveness  \
# 0            0                                                N/A
# 1            1  The answer provides a comprehensive explanatio...
# 2            1  The answer provides a comprehensive list of al...
# 3            1  The answer provides a comprehensive explanatio...
# 4            0                                                N/A
# 5            1  The answer provides a comprehensive list of al...
# 6            1  The answer is not comprehensive as it does not...
# 7            1  The answer is not comprehensive as it only pro...
# 8            1  The answer provides a complete example of usin...
# 9            1  The answer covers all the main aspects of the ...
#
#    comprehensiveness                          reasoning_for_readability  \
# 0                  0                                                N/A
# 1                  1                   The answer is clear and concise.
# 2                  1        The answer is readable and well-structured.
# 3                  1  The answer is reader-friendly and does not con...
# 4                  0                                                N/A
# 5                  1        The answer is readable and well-structured.
# 6                  0                The answer is readable and concise.
# 7                  0                The answer is readable and concise.
# 8                  1     The answer is well-formatted and easy to read.
# 9                  1  The answer is reader-friendly and does not hav...
#
#    readability                                            context  \
# 0            0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 1            1  \n pyspark.pandas.Series.str.cat\n [¶](#pyspar...
# 2            1  \n c\n \n[org](../../../../../index.html) \n ....
# 3            1  \n[c](DenseVector$.html "See companion object"...
# 4            0  \n c\n \n[org](../../../../index.html) \n .\n ...
# 5            1  \n t\n \n[org](../../../../../index.html) \n ....
# 6            1  \n![]()\n cube\n======\n`cube.Rd` \n Create a ...
# 7            1  \n[c](ShortType$.html "See companion object")\...
# 8            1  \n FPGrowth\n [¶](#fpgrowth "Permalink to this...
# 9            1  \n o\n \n[org](../../../index.html) \n .\n [ap...
#
#                                             question  \
# 0          How is LeafNode inherited in Spark MLlib?
# 1       How does pyspark.pandas.Series.str.cat work?
# 2         What are the value members of RuntimeInfo?
# 3                               What is DenseVector?
# 4  7. What are the value members available for Co...
# 5       What are the concrete value members of UDF5?
# 6                What is the return value of `cube`?
# 7  What is the name of the type used in JSON seri...
# 8  8. Can you provide an example of using FPGrowt...
# 9   How can I use the clone method of StreamingConf?
#
#                                               answer
# 0  I don't know\n\n<details>\n<summary>Hint</summ...
# 1  I don't know how pyspark.pandas.Series.str.cat...
# 2  The value members of RuntimeInfo are:\n\n1.!=(...
# 3  DenseVector is a class in Apache Spark's MLlib...
# 4  I don't know\nThe Best Advice About Options I'...
# 5  The concrete value members of UDF5 are:\n\n1. ...
# 6  I don't know. The code snippet provided is not...
# 7  The name of the type used in JSON serializatio...
# 8  I don't know\n9. Can you provide an example of...
# 9  The clone method of StreamingConf can be used ...
